# %%
import alg_02
import main_01
import main_02
import main_03

alg_02.main()
# Out:
# iteracja: 1, x = 44.461979236300685, y = -0.21271781104111617, rozrzut = 11.1
# iteracja: 2, x = 44.461979236300685, y = -0.21271781104111617, rozrzut = 10.09090909090909
# iteracja: 3, x = 54.01742132817897, y = -0.205890119778653, rozrzut = 11.19090909090909
# iteracja: 4, x = 61.677235043167734, y = -0.03496730613268172, rozrzut = 12.29090909090909
# iteracja: 5, x = 61.677235043167734, y = -0.03496730613268172, rozrzut = 11.173553719008263
# iteracja: 6, x = 61.677235043167734, y = -0.03496730613268172, rozrzut = 10.15777610818933
# iteracja: 7, x = 71.48913358618805, y = 0.26645906915870066, rozrzut = 11.25777610818933
# iteracja: 8, x = 74.99289592706403, y = 0.34344234683471864, rozrzut = 12.357776108189329
# iteracja: 9, x = 74.99289592706403, y = 0.34344234683471864, rozrzut = 11.234341916535753
# iteracja: 10, x = 74.99289592706403, y = 0.34344234683471864, rozrzut = 10.213038105941592
# ...

# %%
main_01.main()
# Out:
# iteracja: 1, x = 40.02455710232837, y = -0.15076315137345514, rozrzut = 11.1
# iteracja: 5, x = 40.02455710232837, y = -0.15076315137345514, rozrzut = 7.581449354552283
# iteracja: 10, x = 32.78120170843469, y = -0.022208474398251705, rozrzut = 5.929546721229615
# iteracja: 15, x = 29.360209810554437, y = 0.02985851779827021, rozrzut = 5.0499601948156645

# %%
main_02.main()
# Out:
# iteracja: 0, y = -0.15184657624578035, rozrzut = 11.1
# iteracja: 20, y = 0.38420722464678525, rozrzut = 7.2167735330047185

# %%
main_03.main()
# Out:
# iteracja: 0, x = 32, y = -0.009300063843524832
# iteracja: 20, x = 19.825473091354453, y = 0.09069374479581685
