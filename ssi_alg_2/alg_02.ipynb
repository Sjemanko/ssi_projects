# %% [markdown]
# # Algorytm 1+1 - raport

# %%
import alg_02
import main_01
import main_02
import main_03
import main_04

alg_02.main()
# Out:
# iteracja: 1, x = 56, y = -0.17445410112609297, rozrzut = 9.09090909090909
# iteracja: 2, x = 61.243994554677556, y = -0.047666154505487994, rozrzut = 10.19090909090909
# iteracja: 3, x = 61.243994554677556, y = -0.047666154505487994, rozrzut = 9.264462809917353
# iteracja: 4, x = 62.59987548629611, y = -0.007142266294171469, rozrzut = 10.364462809917352
# iteracja: 5, x = 65.89632185604626, y = 0.09760706040801653, rozrzut = 11.464462809917352
# iteracja: 6, x = 75.81457955346902, y = 0.3564021859113397, rozrzut = 12.564462809917352
# iteracja: 7, x = 75.81457955346902, y = 0.3564021859113397, rozrzut = 11.422238918106682
# iteracja: 8, x = 75.81457955346902, y = 0.3564021859113397, rozrzut = 10.383853561915165
# iteracja: 9, x = 75.81457955346902, y = 0.3564021859113397, rozrzut = 9.439866874468331
# iteracja: 10, x = 75.81457955346902, y = 0.3564021859113397, rozrzut = 8.581697158607573
# iteracja: 11, x = 75.81457955346902, y = 0.3564021859113397, rozrzut = 7.80154287146143
# ...

# %%
main_01.main()
# Out:
# iteracja: 1, x = 34.26076818347858, y = -0.04784374540480117, rozrzut = 11.1
# iteracja: 5, x = 34.26076818347858, y = -0.04784374540480117, rozrzut = 7.581449354552283
# iteracja: 10, x = 30.959639369333317, y = 0.0070326271449296105, rozrzut = 7.7051460214517515
# iteracja: 15, x = 20.998684751557764, y = 0.09047184237199385, rozrzut = 9.367889273927066

# %%
main_02.main()
# Out:
# iteracja: 0, y = -0.09044448245447337, rozrzut = 11.1
# iteracja: 20, y = 0.09082168856881791, rozrzut = 3.4690084244949664

# %%
main_03.main()
# Out:
# iteracja: 0, x = 24.859750611340274, y = 0.07558361752991717
# iteracja: 20, x = 20.30228246231036, y = 0.09082896093470048

# %% [markdown]
# # Algorytm PSO - Particle Swarm Optimization - raport

# %%
import alg_02_02
alg_02_02.main(4, 0, 1, 0, 20, [5])
alg_02_02.main(4, 0.7, 1, 0, 20, [5], alg_02_02.global_static_points)
# Out:
# iteracja: 0
# Położenie najlepszego punktu: (23.447602985150983, 47.94387861435487)
# Położenie najgorszego punktu: (88.78949756002842, 9.042526258984795)
# iteracja: 5
# Położenie najlepszego punktu: (40.14991722770921, 38.49135386178145)
# Położenie najgorszego punktu: (37.84406635417703, 39.84498664907737)
# iteracja: 0
# Położenie najlepszego punktu: (23.447602985150983, 47.94387861435487)
# Położenie najgorszego punktu: (88.78949756002842, 9.042526258984795)
# iteracja: 5
# Położenie najlepszego punktu: (0.0, 92.83697394986851)
# Położenie najgorszego punktu: (0.0, 82.43002502521817)

# %%
alg_02_02.main(4, 0.7, 0.05, 0.8, 20, [3,13])
# Out:
# iteracja: 0
# Położenie najlepszego punktu: (11.054986816382984, 53.16083017503793)
# Położenie najgorszego punktu: (75.61004324604562, 56.405164926760555)
# iteracja: 3
# Położenie najlepszego punktu: (11.054986816382984, 53.16083017503793)
# Położenie najgorszego punktu: (68.77354636346985, 56.06158402631861)
# iteracja: 13
# Położenie najlepszego punktu: (11.054986816382984, 53.16083017503793)
# Położenie najgorszego punktu: (21.074920933132436, 66.76113228416776)

# %%
import alg_02
import main_04
# ZMIANA - WYWOŁANIE ZMIENIONEJ WERSJI ALGORYTMU 1+1
main_04.main()
# Out:
# iteracja: 1, x = 56.849378579536285, y = -0.15793943522938197, rozrzut = 3.3
# iteracja: 5, x = 58.108848123118705, y = -0.1303272364857254, rozrzut = 2.5020482476103774
# iteracja: 10, x = 63.17147161705876, y = 0.010547594955215768, rozrzut = 4.780501921662945
# iteracja: 15, x = 72.61754452371672, y = 0.2946780160231353, rozrzut = 8.277309170509957

# %%
import alg_02_02
alg_02_02.main(4, 0.3, 0.4, 0.8, 20, [2, 4, 6, 10])
# Out:
# iteracja: 0
# Położenie najlepszego punktu: (64.0, 32.0)
# Położenie najgorszego punktu: (58.0, 32.0)
# iteracja: 2
# Położenie najlepszego punktu: (64.0, 32.0)
# Położenie najgorszego punktu: (60.390600174483964, 32.0)
# iteracja: 4
# Położenie najlepszego punktu: (64.0, 32.0)
# Położenie najgorszego punktu: (62.92214189499404, 32.0)
# iteracja: 6
# Położenie najlepszego punktu: (64.0, 32.0)
# Położenie najgorszego punktu: (63.90895879271792, 32.0)
# iteracja: 10
# Położenie najlepszego punktu: (64.0810469016029, 32.0)
# Położenie najgorszego punktu: (64.04511443840632, 32.00057664570842)
